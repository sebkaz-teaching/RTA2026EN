# %% [markdown]
# # Lab 10: Final Project
#
# ## Requirements
#
# Build a complete real-time analytics system in groups of up to 5 people.
#
# ### Architecture
#
# 1. **Data source** -- producer sending events to Kafka
# 2. **Apache Kafka** -- message broker
# 3. **Processing** -- Spark Streaming or Python consumer
# 4. **ML model** -- classification, anomaly detection, or regression
# 5. **Output** -- dashboard, API, file, or alerts
#
# ### Minimum requirements
#
# - Everything runs via `docker compose up`
# - Data flows through Apache Kafka
# - At least one streaming transformation (window, aggregation)
# - ML model (offline or online)
# - README.md with documentation
# - Presentation (5-10 minutes)
#
# ---
#
# ## Suggested Topics
#
# 1. **Fraud detection in banking** (extend our course case)
# 2. **Product review sentiment analysis** (streaming NLP)
# 3. **Dynamic pricing monitor** (price tracking + alerts)
# 4. **E-commerce clickstream** (session analysis, conversion prediction)
# 5. **IoT sensor monitoring** (anomaly detection, predictive maintenance)
#
# ---
#
# ## Today's Tasks

# %%
# Project topic:
# Team members:
# Data source:
# Kafka topics needed:
# ML model type:
# Output format:

# %% [markdown]
# ### Task 1 -- Architecture diagram
#
# Draw your system architecture (use draw.io, Mermaid, or paper).
#
# ### Task 2 -- Producer prototype

# %%
# %%file project_producer.py
# YOUR CODE

# %% [markdown]
# ### Task 3 -- Consumer prototype

# %%
# %%file project_consumer.py
# YOUR CODE

# %% [markdown]
# ### Task 4 -- Docker Compose

# %%
# %%file docker-compose.yml
# # YOUR CODE

# %% [markdown]
# ---
#
# ## Grading
#
# | Criterion | Weight |
# |---|---|
# | Working pipeline (Kafka + processing) | 30% |
# | ML model integrated with the system | 25% |
# | Containerization (Docker Compose) | 20% |
# | Documentation and code quality | 15% |
# | Presentation | 10% |
#
# ## Timeline
#
# | Deadline | Milestone |
# |---|---|
# | **Today** | Topic, architecture, prototypes |
# | **Next week** | Working pipeline + ML model |
# | **2 weeks** | Full Docker Compose + presentation |
